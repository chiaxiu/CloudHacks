# %%
import requests
import json

# %%
data = requests.get('https://api.data.gov.sg/v1/transport/traffic-images')
results = json.loads(data.text)
print(results)
# Out:
# {'items': [{'timestamp': '2024-06-22T11:03:36+08:00', 'cameras': [{'timestamp': '2024-06-22T11:00:16+08:00', 'image': 'https://images.data.gov.sg/api/traffic-images/2024/06/a68b8d8c-abcc-4e98-926e-e6ed278e3ffc.jpg', 'location': {'latitude': 1.29531332, 'longitude': 103.871146}, 'camera_id': '1001', 'image_metadata': {'height': 240, 'width': 320, 'md5': '0453e197f690e3dc4ad0070d7f1255a9'}}, {'timestamp': '2024-06-22T11:00:16+08:00', 'image': 'https://images.data.gov.sg/api/traffic-images/2024/06/3d7db1e2-6b84-4c0c-88d5-70b15cef9eec.jpg', 'location': {'latitude': 1.319541067, 'longitude': 103.8785627}, 'camera_id': '1002', 'image_metadata': {'height': 240, 'width': 320, 'md5': '022bcdf14df432cd591bd847b5b5af18'}}, {'timestamp': '2024-06-22T11:00:16+08:00', 'image': 'https://images.data.gov.sg/api/traffic-images/2024/06/d00a26b2-3216-40db-97f6-cd4a5cca45bb.jpg', 'location': {'latitude': 1.323957439, 'longitude': 103.8728576}, 'camera_id': '1003', 'image_metadata': {'height': 240, 'width
# ...

# %%
count = 0
while count <
